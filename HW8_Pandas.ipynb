# %% [markdown]
# <a href="https://colab.research.google.com/github/Marianderita/ML_Practice/blob/main/HW8_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# У цьому домашньому завданні ми будемо працювати з набором даних Tips. Нижче інформація про нього.
#
# **Про датасет:**
#
# Tips - це датасет, який містить інформацію про рахунки та чайові в ресторані.
#
# **Колонки датасету:**
# - `total_bill` - загальна сума рахунку (долари)
# - `tip` - розмір чайових (долари)
# - `sex` - стать відвідувача (Male/Female)
# - `smoker` - чи курить (Yes/No)
# - `day` - день тижня (Thur/Fri/Sat/Sun)
# - `time` - час відвідування (Lunch/Dinner)
# - `size` - розмір групи (кількість людей)
#
# **Джерело:** Оригінальні дані зібрані в одному з американських ресторанів у 1990-х роках. Скачати і переглянути набір даних можна тут: https://www.kaggle.com/datasets/sakshisatre/tips-dataset
#
# А також ми вже вивантажили файл з даними і завантажили вам у Матеріали до цього модуля.

# %% [markdown]
# **1. Завантаження та огляд**
#
# Завантажте датасет Tips (Чайові) з файла у матеріалах `tips.csv`.
#
# Виведіть (кожен пункт оцінюється в 0.5 бала):
# - Перші 5 рядків
# - Розмір датасету (shape)
# - Назви всіх колонок
# - Інформацію про типи даних (info)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data_path = '/content/drive/MyDrive/Python/ML/Data/tips.csv'
df = pd.read_csv(data_path)

# %%
# Перші 5 рядків
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Розмір датасету (shape)
df.shape
# Out:
# (244, 7)

# %%
# Назви всіх колонок
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Інформація про типи даних (info)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# **2. Базова вибірка даних**
#
# Виберіть та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Колонку `total_bill` (загальний рахунок)
# - Колонки `total_bill` та `tip` (чайові) разом
# - Перші 10 рядків
# - Рядок з індексом 5

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[:10]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
display(df.loc[5])
# або
display(df[5:6])
# Out:
# total_bill         25.29
# tip                 4.71
# sex                 Male
# smoker                No
# day                  Sun
# time              Dinner
# size                   4
# tip_percentage      0.19
# Name: 5, dtype: object
#    total_bill   tip   sex smoker  day    time  size  tip_percentage
# 5       25.29  4.71  Male     No  Sun  Dinner     4            0.19

# %% [markdown]
# **3. Фільтрація даних**
#
# Відфільтруйте повний набір даних та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Всі рахунки більше 20 доларів (`total_bill > 20`)
# - Всі відвідувачі-жінки (`sex == 'Female'`)
# - Рахунки на вечерю (`time == 'Dinner'`)
# - Рахунки на вечерю з сумою чеку більше 30 доларів
#
# Для виведення результатів фільтрації:
# - зберегти результат у окрему змінну
# - показати кількість записів у відфільтрованому наборі
# - вивести перші 5 записів відфільтрованого набору.

# %%
# Всі рахунки більше 20 доларів (total_bill > 20)
df1 = df[df['total_bill'] > 20]

# Всі відвідувачі-жінки (sex == 'Female')
df2 = df[df.sex == 'Female']

# Рахунки на вечерю (time == 'Dinner')
df3 = df[df.time == 'Dinner']

# Рахунки на вечерю з сумою чеку більше 30 доларів
df4 = df[df.total_bill >= 30]

# %%
print(f"К-сть записів 1-го датасету: {len(df1)}")
display(df1.head())

print(f"\nК-сть записів 2-го датасету: {len(df2)}")
display(df2.head())

print(f"\nК-сть записів 3-го датасету: {len(df3)}")
display(df3.head())

print(f"\nК-сть записів 4-го датасету: {len(df4)}")
display(df4.head())
# Out:
# К-сть записів 1-го датасету: 97
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# К-сть записів 2-го датасету: 87
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
# К-сть записів 3-го датасету: 176
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# К-сть записів 4-го датасету: 32
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 39       31.27  5.00    Male     No  Sat  Dinner     3
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4

# %% [markdown]
# ---
#
# **4. Описова статистика**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній розмір рахунку на всьому наборі даних
# - Максимальні чайові
# - Кількість пропущених значень у всіх колонках
# - Скільки в наборі даних рахунків за обіди і за вечері

# %%
avg_bill = df.total_bill.mean().round(1)
max_tip = df.tip.max()
nulls = df.isnull().sum().sum()
time_bills = df.groupby(['time']).size()
df.groupby(['time']).size()
print(f'Середній розмір рахунку: {avg_bill}')
print(f"\nМаксимальні чайові: {max_tips}")
print(f"\nКількість пропущених значень у всіх колонках: {nulls}")
print(f"\nКількість рахунків за обіди і за вечері: \n{time_bills}")
# Out:
# Середній розмір рахунку: 19.8
#
# Максимальні чайові: 10.0
#
# Кількість пропущених значень у всіх колонках: 0
#
# Кількість рахунків за обіди і за вечері:
# time
# Dinner    176
# Lunch      68
# dtype: int64

# %% [markdown]
# ---
#
# **5. Статистика із групуванням**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній рахунок за статтю (groupby `sex`)
# - Середні чайові за днем тижня (groupby `day`)
# - Скільки відвідувачів у кожен день

# %%
# Середній рахунок за статтю (groupby sex)
df.groupby('sex').agg({'total_bill': 'mean'}).round(2)
# Out:
#         total_bill
# sex
# Female       18.06
# Male         20.74

# %%
# Середні чайові за днем тижня (groupby day)
df.groupby('day').agg({'tip': 'mean'}).round(2)
# Out:
#        tip
# day
# Fri   2.73
# Sat   2.99
# Sun   3.26
# Thur  2.77

# %%
# Скільки відвідувачів у кожен день
df.groupby('day').agg({'size': 'sum'}).round(2)
# Out:
#       size
# day
# Fri     40
# Sat    219
# Sun    216
# Thur   152

# %% [markdown]
# ---
#
# **6. Створення нової колонки**
#
# Створіть нову колонку `tip_percentage` - відсоток чайових від загальної суми рахунку.
# Виведіть перші 10 рядків з новою колонкою.

# %%
df['tip_percentage'] = (df.tip / df.total_bill).round(2)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2            0.06
# 1       10.34  1.66    Male     No  Sun  Dinner     3            0.16
# 2       21.01  3.50    Male     No  Sun  Dinner     3            0.17
# 3       23.68  3.31    Male     No  Sun  Dinner     2            0.14
# 4       24.59  3.61  Female     No  Sun  Dinner     4            0.15

# %% [markdown]
# ---
#
# **7. Сортування**
#
# Відсортуйте датасет і виведіть результат сортування в кожному випадку окремо (кожен пункт оцінюється в 0.5 бала):
# - За розміром рахунку (зростання)
# - За чайовими (спадання)
#
# Додатково виведіть топ-5 найбільших чайових використовуючи метод `nlargest`.

# %%
df_sorted_1 = df.sort_values('total_bill')
display(df_sortet_1.head())
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_percentage
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1            0.33
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2            0.17
# 111        7.25  1.00  Female     No   Sat  Dinner     1            0.14
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2            0.71
# 149        7.51  2.00    Male     No  Thur   Lunch     2            0.27

# %%
df_sorted_2 = df.sort_values('tip', ascending=False)
display(df_sortet_2.head())
# Out:
#      total_bill    tip   sex smoker   day    time  size  tip_percentage
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3            0.20
# 212       48.33   9.00  Male     No   Sat  Dinner     4            0.19
# 23        39.42   7.58  Male     No   Sat  Dinner     4            0.19
# 59        48.27   6.73  Male     No   Sat  Dinner     4            0.14
# 141       34.30   6.70  Male     No  Thur   Lunch     6            0.20

# %%
top_tips = df.nlargest(5, 'tip')['tip']
display(top_tips)
# Out:
# 170    10.00
# 212     9.00
# 23      7.58
# 59      6.73
# 141     6.70
# Name: tip, dtype: float64
