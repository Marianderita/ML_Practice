# %% [markdown]
# <a href="https://colab.research.google.com/github/Marianderita/ML_Practice/blob/main/HW2_%D0%A1%D0%BF%D0%B8%D1%81%D0%BA%D0%B8_%D1%82%D0%B0_%D1%81%D0%BB%D0%BE%D0%B2%D0%BD%D0%B8%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Списки - базові операції**
#
# Створіть список температур за тиждень (у градусах Цельсія) з назвою
# `temperatures` і значеннями [22, 25, 19, 23, 26, 20, 21, 22].
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть перший елемент
# - Виведіть останній елемент
# - Додайте температуру 24
# - Видаліть температуру 19
# - Виведіть довжину списку
# - Обчисліть суму всіх температур
# - Знайдіть максимальну температуру

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]
print("тип: ", type(temperatures))
print("перший елемент: ", temperatures[0])
print("останній елемент: ", temperatures[-1])

temperatures.append(24)
print("з новим елементом 24: ", temperatures)

temperatures.remove(19)
print("без елемента 19: ", temperatures)

print("довжина списку: ", len(temperatures))
print("сума елементів: ", sum(temperatures))
print("макс значення в списку: ", max(temperatures))
# Out:
# тип:  <class 'list'>
# перший елемент:  22
# останній елемент:  22
# з новим елементом 24:  [22, 25, 19, 23, 26, 20, 21, 22, 24]
# без елемента 19:  [22, 25, 23, 26, 20, 21, 22, 24]
# довжина списку:  8
# сума елементів:  183
# макс значення в списку:  26

# %% [markdown]
# **2. Словники - базові операції**
#
# Створіть словник про себе, який містить ключі `name`, `age`, `city` і значення, які відповідають вашему імені, віку і місту (можна вставити будь-які значення, не обовʼязково свої).
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть значення ключа "name"
# - Змініть значення ключа "age" на 21
# - Додайте новий ключ "hobby" зі значенням "programming"
# - Виведіть всі ключі
# - Виведіть всі значення

# %%
dict_me = {
    "name": "Marianna",
    "age": 27,
    "city": "Kyiv"
}

print(dict_me)

# значення ключа "name"
print(dict_me["name"])

# зміна значення ключа "age" на 21
dict_me['age'] = 21
print(dict_me['age'])

# новий ключ "hobby" зі значенням "programming"
dict_me["hobby"] = "programming"
print(dict_me)

# всі ключі
print(dict_me.keys())

# всі значення
print(dict_me.values())
# Out:
# {'name': 'Marianna', 'age': 27, 'city': 'Kyiv'}
# Marianna
# 21
# {'name': 'Marianna', 'age': 21, 'city': 'Kyiv', 'hobby': 'programming'}
# dict_keys(['name', 'age', 'city', 'hobby'])
# dict_values(['Marianna', 21, 'Kyiv', 'programming'])
